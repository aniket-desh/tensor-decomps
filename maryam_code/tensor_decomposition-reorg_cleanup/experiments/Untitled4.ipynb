# %%
import numpy as np


# sample positions
# Define spatial density function rho(x)
def rho(x):
    return np.exp(-np.linalg.norm(x)**2)

# Discretize spatial domain
x_grid = np.linspace(-1, 1, 10)
y_grid = np.linspace(-1, 1, 10)
X, Y = np.meshgrid(x_grid, y_grid)
positions = np.column_stack((X.flatten(), Y.flatten()))
#print(positions)
densities = rho(positions)
# Normalize densities to form a probability distribution
probabilities = densities / np.sum(densities)
print(densities)
print(probabilities)

# Sample positions based on rho(x)
num_samples = 10
sampled_positions_indices = np.random.choice(len(positions), size=num_samples, p=probabilities)
print(sampled_positions_indices)
sampled_positions = positions[sampled_positions_indices]
print(sampled_positions)
# Out:
# 4.102439785267787e-36
# 1.0
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#   File "/tmp/ipykernel_44535/214697664.py", line 23, in <module>
#     sampled_positions_indices = np.random.choice(len(positions), size=num_samples, p=probabilities)
#                                 ^^^^^^^^^
#   File "/usr/lib/python3.12/site-packages/numpy/__init__.py", line 337, in __getattr__
# ModuleNotFoundError: No module named 'numpy.random'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/site-packages/pygments/styles/__init__.py", line 45, in get_style_by_name
# ModuleNotFoundError: No module named 'pygments.styles.default'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2168, in showtraceback
#   File "/usr/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1457, in structured_traceback
#   File "/usr/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1348, in structured_traceback
#   File "/usr/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1195, in structured_traceback
#   File "/usr/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1085, in format_exception_as_a_whole
#   File "/usr/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1136, in get_records
#   File "/usr/lib/python3.12/site-packages/pygments/styles/__init__.py", line 47, in get_style_by_name
# pygments.util.ClassNotFound: Could not find style module 'pygments.styles.default', though it should be builtin.
