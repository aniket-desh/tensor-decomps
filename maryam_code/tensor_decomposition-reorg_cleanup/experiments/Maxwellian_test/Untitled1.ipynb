# %%
import sympy as sp

x = sp.symbols('x')
v = sp.symbols('v')
d_v = 1
rho = 1.0
delta = 5e-3  
u = delta * sp.sin(2 * sp.pi * x) 
T = 1.0 + 0.001 * x  
ana_MW = maxwellian_ana(d_v, rho, u, T, v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 u = delta * sp.sin(2 * sp.pi * x)
#       9 T = 1.0 + 0.001 * x
# ---> 10 ana_MW = maxwellian_ana(d_v, rho, u, T, v)
#
# NameError: name 'maxwellian_ana' is not defined
